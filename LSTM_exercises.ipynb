# %% [markdown]
# ## Exercise 1
#
#  - Import Barcelona_air_pollution data
#  - Make a descriptive analysis to find the most interessting series to predict, for example you can answer your self if pollution levels are higher or lower during specific year seasons or parts of the day.
#  - Train a LSTM NN and use the last 6 months history to validate (3 months) and test (3 months).
#  - You can use weather data to improve your modelling and predictions.

# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
air_pol = pd.read_csv('drive/MyDrive/Barcelona_air_pollution.csv',sep=";")

# %%
air_pol
# Out:
#            lon    lat      CO   NO   NO2     O3   SO2  PM2_5   PM10   NH3  \
# 0      41.3888  2.159  243.66  0.0  0.07  41.84  0.07   5.12  11.97  0.41
# 1      41.3888  2.159  233.65  0.0  0.08  44.35  0.07   5.52  14.40  0.38
# 2      41.3888  2.159  226.97  0.0  0.08  46.49  0.06   5.83  16.02  0.34
# 3      41.3888  2.159  223.64  0.0  0.08  46.49  0.06   6.08  16.92  0.30
# 4      41.3888  2.159  220.30  0.0  0.09  46.49  0.06   6.44  17.89  0.26
# ...        ...    ...     ...  ...   ...    ...   ...    ...    ...   ...
# 17324  41.3888  2.159  216.96  0.0  0.07  40.05  0.05   2.71   5.42  0.37
# 17325  41.3888  2.159  216.96  0.0  0.07  38.98  0.05   3.10   6.23  0.40
# 17326  41.3888  2.159  213.62  0.0  0.07  41.13  0.09   4.61   9.95  0.41
# 17327  41.3888  2.159  210.29  0.0  0.06  45.06  0.11   5.32  12.26  0.36
# 17328  41.3888  2.159  213.62  0.0  0.06  48.64  0.09   4.33  10.00  0.30
#
#        aqi        date  hour  year       city
# 0        1  01/01/2021     0  2021  Barcelona
# 1        1  01/01/2021     1  2021  Barcelona
# 2        1  01/01/2021     2  2021  Barcelona
# 3        1  01/01/2021     3  2021  Barcelona
# 4        1  01/01/2021     4  2021  Barcelona
# ...    ...         ...   ...   ...        ...
# 17324    1  31/12/2022    20  2022  Barcelona
# 17325    1  31/12/2022    21  2022  Barcelona
# 17326    1  31/12/2022    22  2022  Barcelona
# 17327    1  31/12/2022    23  2022  Barcelona
# 17328    1  01/01/2023     0  2023  Barcelona
#
# [17329 rows x 15 columns]

# %%
air_pol['date_hour0'] = air_pol['date'] + ' ' + air_pol['hour'].astype(str)
air_pol['date_hour'] = pd.to_datetime(air_pol['date_hour0'], format = '%d/%m/%Y %H')
air_pol.drop(['date','hour','date_hour0'], axis = 1, inplace = True)
air_pol.tail(5)
# Out:
#            lon    lat      CO   NO   NO2     O3   SO2  PM2_5   PM10   NH3  \
# 17324  41.3888  2.159  216.96  0.0  0.07  40.05  0.05   2.71   5.42  0.37
# 17325  41.3888  2.159  216.96  0.0  0.07  38.98  0.05   3.10   6.23  0.40
# 17326  41.3888  2.159  213.62  0.0  0.07  41.13  0.09   4.61   9.95  0.41
# 17327  41.3888  2.159  210.29  0.0  0.06  45.06  0.11   5.32  12.26  0.36
# 17328  41.3888  2.159  213.62  0.0  0.06  48.64  0.09   4.33  10.00  0.30
#
#        aqi  year       city           date_hour
# 17324    1  2022  Barcelona 2022-12-31 20:00:00
# 17325    1  2022  Barcelona 2022-12-31 21:00:00
# 17326    1  2022  Barcelona 2022-12-31 22:00:00
# 17327    1  2022  Barcelona 2022-12-31 23:00:00
# 17328    1  2023  Barcelona 2023-01-01 00:00:00

# %%
weather = pd.read_csv('drive/MyDrive/Barcelona_weather.csv', sep = ';')

weather['date'] = pd.to_datetime(weather['dt'],unit='s')
weather = weather[['date','temp','feels_like','pressure','humidity','wind_speed','dew_point', 'visibility','rain_1h']]
weather['rain_1h'].fillna(0, inplace = True)
weather['year'] = weather['date'].dt.year
weather['month'] = weather['date'].dt.month
weather = weather[weather['year'].isin([2018,2019,2020,2021,2022])]

def nans(df):
  for c in df.columns:
    df[c].bfill(inplace = True)
  return df

weather = nans(weather)

weather.drop_duplicates(inplace = True)
weather.reset_index(inplace = True)
weather.drop(['index'], axis = 1, inplace = True);
weather.head(3)
# Out:
#                  date   temp  feels_like  pressure  humidity  wind_speed  \
# 0 2018-01-01 00:00:00  14.63       13.61      1018        56         9.3
# 1 2018-01-01 01:00:00  13.31       12.05      1019        52         6.7
# 2 2018-01-01 02:00:00  12.35       11.10      1020        56         6.7
#
#    dew_point  visibility  rain_1h  year  month
# 0       5.96     10000.0      0.0  2018      1
# 1       3.67     10000.0      0.0  2018      1
# 2       3.83     10000.0      0.0  2018      1

# %%
air_pol = air_pol.merge(weather, left_on = 'date_hour', right_on = 'date', how = 'left')
air_pol.columns
# Out:
# Index(['lon', 'lat', 'CO', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3',
#        'aqi', 'year_x', 'city', 'date_hour', 'date', 'temp', 'feels_like',
#        'pressure', 'humidity', 'wind_speed', 'dew_point', 'visibility',
#        'rain_1h', 'year_y', 'month'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 7))
fig, ax = plt.subplots(figsize=(12, 7))
# ax2 = ax.twinx()

ax.plot(air_pol['date_hour'], air_pol['CO'], color = 'blue', label = 'CO')
plt.legend()
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(12, 7))
fig, ax = plt.subplots(figsize=(12, 7))
# ax2 = ax.twinx()

ax.plot(air_pol['date_hour'], air_pol['PM2_5'], color = 'blue', label = 'PM2_5')
plt.legend()
plt.xticks(rotation=45);

# %%
air_plot_train = air_pol[air_pol['date_hour']<='2022-06-30 23:00:0']
air_plot_val = air_pol[air_pol['date_hour'].between('2022-06-30 23:00:0','2022-09-30 23:00:0')]
air_plot_test = air_pol[air_pol['date_hour']>'2022-09-30 23:00:0']

air_plot_train.drop(['lon','lat','city','aqi','year_x','year_y', 'date', 'rain_1h', 'visibility', 'month'], axis = 1, inplace = True)
air_plot_val.drop(['lon','lat','city','aqi','year_x','year_y', 'date', 'rain_1h', 'visibility', 'month'], axis = 1, inplace = True)
air_plot_test.drop(['lon','lat','city','aqi','year_x','year_y', 'date', 'rain_1h', 'visibility', 'month'], axis = 1, inplace = True)

air_plot_train.columns = ['CO', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3','date', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed', 'dew_point']
air_plot_val.columns = ['CO', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3','date', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed', 'dew_point']
air_plot_test.columns = ['CO', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3','date', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed', 'dew_point']


air_plot_train.head(3)
# Out:
#        CO   NO   NO2     O3   SO2  PM2_5   PM10   NH3                date  \
# 0  243.66  0.0  0.07  41.84  0.07   5.12  11.97  0.41 2021-01-01 00:00:00
# 1  233.65  0.0  0.08  44.35  0.07   5.52  14.40  0.38 2021-01-01 01:00:00
# 2  226.97  0.0  0.08  46.49  0.06   5.83  16.02  0.34 2021-01-01 02:00:00
#
#    temp  feels_like  pressure  humidity  wind_speed  dew_point
# 0  9.11        8.43    1007.0      71.0         1.7       4.14
# 1  8.46        7.31    1006.0      73.0         2.1       3.91
# 2  8.14        6.94    1006.0      75.0         2.1       3.98

# %%
columns_to_use=['NO',"CO", 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed', 'dew_point']

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
air_plot_train_scaled = pd.DataFrame(sc.fit_transform(air_plot_train[columns_to_use]),columns=columns_to_use)
air_plot_val_scaled = pd.DataFrame(sc.fit_transform(air_plot_val[columns_to_use]),columns=columns_to_use)
air_plot_test_scaled = pd.DataFrame(sc.fit_transform(air_plot_test[columns_to_use]),columns=columns_to_use)

# %%
X_train=air_plot_train_scaled[columns_to_use]
y_train=air_plot_train_scaled["CO"]
X_test=air_plot_test_scaled[columns_to_use]
y_test=air_plot_test_scaled["CO"]
X_val=air_plot_val_scaled[columns_to_use]
y_val=air_plot_val_scaled["CO"]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13031, 14) (13031,)
# (2138, 14) (2138,)

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []

    for i in range(len(X) - time_steps):
      v = X.iloc[i:(i + time_steps)].values
      Xs.append(v)
      ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 1

# reshape to [samples, time_steps, n_features]

X_train_shape, y_train_shape = create_dataset(X_train, y_train, time_steps)
X_test_shape, y_test_shape = create_dataset(X_test, y_test, time_steps)
X_val_shape, y_val_shape = create_dataset(X_val, y_val, time_steps)

print(X_train_shape.shape, y_train.shape)
# Out:
# (13030, 1, 14) (13031,)

# %%
lstm_model = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.LSTM(16,activation='relu', return_sequences = True, input_shape = (X_train_shape.shape[1], X_train_shape.shape[2])),
    tf.keras.layers.LSTM(16,activation='relu'),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(units=1)
  ])
lstm_model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError(),tf.metrics.MeanAbsolutePercentageError()])
history = lstm_model.fit(X_train_shape, y_train_shape, validation_data = (X_val_shape, y_val_shape), epochs=50, batch_size = 100)

ypred_shape = lstm_model.predict(X_test_shape)

_, mae_tr, acc_tr = lstm_model.evaluate(X_train_shape, y_train_shape)
_, mae_ts, acc_ts = lstm_model.evaluate(X_test_shape, y_test_shape)
print('MAE train: %.2f; Acc train: %.2f' % (mae_tr, acc_tr))
print('MAE test: %.2f; Acc test: %.2f' % (mae_ts, acc_ts))
# Out:
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 131/131 [==============================] - 5s 22ms/step - loss: 0.0303 - mean_absolute_error: 0.1325 - mean_absolute_percentage_error: 17833.1191 - val_loss: 0.0173 - val_mean_absolute_error: 0.1070 - val_mean_absolute_percentage_error: 213313.9219
# Epoch 2/50
# 131/131 [==============================] - 2s 18ms/step - loss: 0.0069 - mean_absolute_error: 0.0609 - mean_absolute_percentage_error: 13736.9570 - val_loss: 0.0098 - val_mean_absolute_error: 0.0843 - val_mean_absolute_percentage_error: 153190.3750
# Epoch 3/50
# 131/131 [==============================] - 2s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - mean_absolute_percentage_error: 11184.5576 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385 - val_mean_absolute_percentage_error: 69017.0000
# Epoch 4/50
# 131/131 [==============================] - 1s 9ms/step - loss: 5.6148e-04 - mean_absolute_error: 0.0162 - mean_absolute_percentage_error: 5960.4038 - val_loss: 0.0022 - val_mean_absolute_error: 0.0364 - val_mean_absolute_percentage_error: 53699.6523
# Epoch 5/50
# 131/131 [==============================] - 1s 10ms/step - loss: 5.1157e-04 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 5909.1255 - val_loss: 0.0018 - val_mean_absolute_error: 0.0295 - val_mean_absolute_percentage_error: 51215.3203
# Epoch 6/50
# 131/131 [==============================] - 1s 9ms/step - loss: 4.6174e-04 - mean_absolute_error: 0.0143 - mean_absolute_percentage_error: 5040.3232 - val_loss: 0.0017 - val_mean_absolute_error: 0.0295 - val_mean_absolute_percentage_error: 37276.2344
# Epoch 7/50
# 131/131 [==============================] - 1s 9ms/step - loss: 4.2341e-04 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 4420.7749 - val_loss: 0.0015 - val_mean_absolute_error: 0.0274 - val_mean_absolute_percentage_error: 31572.1113
# Epoch 8/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.9701e-04 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 3789.0864 - val_loss: 0.0015 - val_mean_absolute_error: 0.0273 - val_mean_absolute_percentage_error: 26493.4141
# Epoch 9/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.9113e-04 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 3572.0520 - val_loss: 0.0014 - val_mean_absolute_error: 0.0257 - val_mean_absolute_percentage_error: 28502.6465
# Epoch 10/50
# 131/131 [==============================] - 1s 11ms/step - loss: 3.7851e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 3427.9341 - val_loss: 0.0014 - val_mean_absolute_error: 0.0267 - val_mean_absolute_percentage_error: 24547.4570
# Epoch 11/50
# 131/131 [==============================] - 2s 17ms/step - loss: 3.7475e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 3231.4895 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262 - val_mean_absolute_percentage_error: 25911.8926
# Epoch 12/50
# 131/131 [==============================] - 2s 18ms/step - loss: 3.7215e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 3264.1277 - val_loss: 0.0013 - val_mean_absolute_error: 0.0249 - val_mean_absolute_percentage_error: 27018.7402
# Epoch 13/50
# 131/131 [==============================] - 3s 20ms/step - loss: 3.6791e-04 - mean_absolute_error: 0.0127 - mean_absolute_percentage_error: 3056.0283 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255 - val_mean_absolute_percentage_error: 26420.6406
# Epoch 14/50
# 131/131 [==============================] - 2s 16ms/step - loss: 3.6221e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 3156.5918 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268 - val_mean_absolute_percentage_error: 25656.6621
# Epoch 15/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.6118e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 3222.9722 - val_loss: 0.0013 - val_mean_absolute_error: 0.0259 - val_mean_absolute_percentage_error: 26086.3750
# Epoch 16/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.5729e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2786.1672 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265 - val_mean_absolute_percentage_error: 24792.8184
# Epoch 17/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.5536e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2923.2053 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269 - val_mean_absolute_percentage_error: 28249.6582
# Epoch 18/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.5685e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2976.1233 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276 - val_mean_absolute_percentage_error: 25211.5801
# Epoch 19/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.5156e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2732.2795 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278 - val_mean_absolute_percentage_error: 22673.5156
# Epoch 20/50
# 131/131 [==============================] - 1s 11ms/step - loss: 3.5374e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2862.9751 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266 - val_mean_absolute_percentage_error: 26374.1270
# Epoch 21/50
# 131/131 [==============================] - 2s 19ms/step - loss: 3.5284e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2352.6414 - val_loss: 0.0013 - val_mean_absolute_error: 0.0260 - val_mean_absolute_percentage_error: 25444.7949
# Epoch 22/50
# 131/131 [==============================] - 2s 18ms/step - loss: 3.5332e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2715.0305 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271 - val_mean_absolute_percentage_error: 24171.7363
# Epoch 23/50
# 131/131 [==============================] - 2s 14ms/step - loss: 3.4982e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2289.2830 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268 - val_mean_absolute_percentage_error: 26345.2539
# Epoch 24/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.5897e-04 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 1819.4919 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321 - val_mean_absolute_percentage_error: 19464.6582
# Epoch 25/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.5538e-04 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 2507.9954 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294 - val_mean_absolute_percentage_error: 23731.0430
# Epoch 26/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4805e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2014.4941 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283 - val_mean_absolute_percentage_error: 21027.5469
# Epoch 27/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4852e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2266.1987 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255 - val_mean_absolute_percentage_error: 24534.0332
# Epoch 28/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4712e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 1520.4835 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287 - val_mean_absolute_percentage_error: 18396.5508
# Epoch 29/50
# 131/131 [==============================] - 2s 16ms/step - loss: 3.4675e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2171.2144 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268 - val_mean_absolute_percentage_error: 24693.4336
# Epoch 30/50
# 131/131 [==============================] - 1s 11ms/step - loss: 3.4537e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1873.9203 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292 - val_mean_absolute_percentage_error: 25731.0742
# Epoch 31/50
# 131/131 [==============================] - 3s 22ms/step - loss: 3.5061e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 2061.4453 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280 - val_mean_absolute_percentage_error: 23044.3984
# Epoch 32/50
# 131/131 [==============================] - 3s 21ms/step - loss: 3.4345e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 2014.5442 - val_loss: 0.0017 - val_mean_absolute_error: 0.0322 - val_mean_absolute_percentage_error: 17141.7578
# Epoch 33/50
# 131/131 [==============================] - 1s 11ms/step - loss: 3.4106e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 2009.5764 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271 - val_mean_absolute_percentage_error: 24146.1699
# Epoch 34/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4365e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1749.4989 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300 - val_mean_absolute_percentage_error: 19424.9434
# Epoch 35/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4361e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1736.7437 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291 - val_mean_absolute_percentage_error: 19451.1211
# Epoch 36/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4141e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1976.4681 - val_loss: 0.0017 - val_mean_absolute_error: 0.0315 - val_mean_absolute_percentage_error: 15698.3076
# Epoch 37/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4193e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1510.3521 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294 - val_mean_absolute_percentage_error: 19662.8281
# Epoch 38/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.5231e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 2093.6306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276 - val_mean_absolute_percentage_error: 21216.5957
# Epoch 39/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4246e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1536.9188 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266 - val_mean_absolute_percentage_error: 17674.4297
# Epoch 40/50
# 131/131 [==============================] - 1s 11ms/step - loss: 3.4199e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1519.1050 - val_loss: 0.0013 - val_mean_absolute_error: 0.0257 - val_mean_absolute_percentage_error: 21326.1113
# Epoch 41/50
# 131/131 [==============================] - 2s 18ms/step - loss: 3.4376e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 2051.1133 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269 - val_mean_absolute_percentage_error: 20992.9316
# Epoch 42/50
# 131/131 [==============================] - 2s 18ms/step - loss: 3.4122e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1160.6704 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305 - val_mean_absolute_percentage_error: 17208.1250
# Epoch 43/50
# 131/131 [==============================] - 2s 15ms/step - loss: 3.3928e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1655.2109 - val_loss: 0.0014 - val_mean_absolute_error: 0.0276 - val_mean_absolute_percentage_error: 20650.8398
# Epoch 44/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.3973e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1456.6261 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293 - val_mean_absolute_percentage_error: 21737.4473
# Epoch 45/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4278e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 1504.8986 - val_loss: 0.0018 - val_mean_absolute_error: 0.0330 - val_mean_absolute_percentage_error: 13525.0977
# Epoch 46/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4640e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 1306.7715 - val_loss: 0.0016 - val_mean_absolute_error: 0.0304 - val_mean_absolute_percentage_error: 18158.5293
# Epoch 47/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.3977e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 1776.8273 - val_loss: 0.0014 - val_mean_absolute_error: 0.0272 - val_mean_absolute_percentage_error: 20046.0020
# Epoch 48/50
# 131/131 [==============================] - 1s 9ms/step - loss: 3.4512e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 1207.6272 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294 - val_mean_absolute_percentage_error: 20083.2012
# Epoch 49/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4198e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 1467.5321 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287 - val_mean_absolute_percentage_error: 18088.4512
# Epoch 50/50
# 131/131 [==============================] - 1s 10ms/step - loss: 3.4571e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 1598.7297 - val_loss: 0.0015 - val_mean_absolute_error: 0.0296 - val_mean_absolute_percentage_error: 20181.1133
# 67/67 [==============================] - 0s 2ms/step
# 408/408 [==============================] - 2s 4ms/step - loss: 3.3079e-04 - mean_absolute_error: 0.0117 - mean_absolute_percentage_error: 1528.3596
# 67/67 [==============================] - 0s 5ms/step - loss: 6.8195e-04 - mean_absolute_error: 0.0177 - mean_absolute_percentage_error: 11444.9854
# MAE train: 0.01; Acc train: 1528.36
# MAE test: 0.02; Acc test: 11444.99

# %% [markdown]
# ## Validation plots

# %% [markdown]
# MAPE tan alto supongo por trabajar con valores muy cercanos a 0

# %%
plt.subplot(211)
plt.title('mean_absolute_error')
plt.plot(history.history['mean_absolute_error'], label='train')
plt.plot(history.history['val_mean_absolute_error'], label='test')
plt.legend()

# %%
# plt.plot(np.arange(0, len(y_CO_train_shape)), y_CO_train_shape.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train_shape), len(y_train_shape) + len(y_test_shape)), y_test_shape.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train_shape), len(y_train_shape) + len(y_test_shape)), ypred_shape.flatten(), 'r', label="prediction")
plt.ylabel('CO')
plt.xlabel('Time Step')
plt.legend()
plt.show();
